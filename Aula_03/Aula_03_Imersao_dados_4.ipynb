# %% [markdown]
# <a href="https://colab.research.google.com/github/Augusto-c-s/Dados/blob/main/Aula_03_Imersao_dados_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                              Rua                    Bairro     Cidade  \
# 7998                         NaN                 Vila Nair  São Paulo
# 3842            Rua Raul Pompéia              Vila Pompéia  São Paulo
# 2246                         NaN                  Pacaembu  São Paulo
# 6974                Rua Ipiranga          Jardim Aeroporto  São Paulo
# 1687           Rua Alberto Faria         Alto de Pinheiros  São Paulo
# 6343                         NaN                    Sumaré  São Paulo
# 496          Rua Barão de Loreto  Vila São José (Ipiranga)  São Paulo
# 3015  Rua Filipe de Gusmão, 158                Sumarezinho  São Paulo
# 9462        Rua Dom Joaquim Luna           Jardim Domitila  São Paulo
# 7988                         NaN                     Saúde  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 7998       124        2          1      2
# 3842       165        3          5      2
# 2246       450        4          5      3
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Bairro"][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
tem_imoveis_vila =( dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Valor"][0]
# Out:
# 'R$ 7.000.000'

# %%
dados["Valor"][0].split()
# Out:
# ['R$', '7.000.000']

# %%
dados.sample(10)
# Out:
#                                   Rua              Bairro     Cidade  \
# 5060               Rua Blumenau, 105      Vila Leopoldina  São Paulo
# 5063                              NaN  Quinta da Paineira  São Paulo
# 3699                  Rua Ícaro Sydow             Morumbi  São Paulo
# 278   Rua Nélio Batista Guimarães, 0     Parque Boturussu  São Paulo
# 4767                              NaN            Pacaembu  São Paulo
# 2097                   Rua Petrópolis              Sumaré  São Paulo
# 7731                              NaN   Vila Bela Aliança  São Paulo
# 6642        Travessa Umberto Bignardi             Paraíso  São Paulo
# 3485                              NaN             Boaçava  São Paulo
# 7046                              NaN          Vila Lúcia  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas         Valor
# 5060       130        3          4      2    R$ 695.000
# 5063       265        3          3      3    R$ 720.000
# ...

# %%
dados["Valor"].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
len(dados["Valor"].str.split(expand = True)[1].unique())
# Out:
# 1038

# %%
dados["Valor"].str.split(expand = True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
dados[["Valor", "Bairro"]]
# Out:
#                                       Valor              Bairro
# 0                              R$ 7.000.000   Planalto Paulista
# 1                              R$ 3.700.000  Jardim dos Estados
# 2                                R$ 380.000     Jardim Reimberg
# 3                                R$ 685.000      Jardim Morumbi
# 4                                R$ 540.000               Mooca
# ...                                     ...                 ...
# 10003                            R$ 665.000          Vila Sofia
# 10004                          R$ 2.300.000     Bosque da Saúde
# 10005                          R$ 1.050.000       Vila da Saúde
# 10006  R$ 2.200\n                      /Mês       Vila Oratório
# 10007                            R$ 270.000         Vila Alpina
#
# [10008 rows x 2 columns]

# %%
dados[["Moeda", "Valor_anuncio", "Tipo_anuncio"]] = dados["Valor"].str.split(expand = True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %%
dados[dados["Tipo_anuncio"].isnull()]["Tipo_anuncio"].unique()
# Out:
# array([None], dtype=object)

# %%
dados_vendas = dados[dados["Tipo_anuncio"].isnull()]
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   object
#  10  Tipo_anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0        7000000.0
# 1        3700000.0
# 2         380000.0
# 3         685000.0
# 4         540000.0
#            ...
# 10002    1500000.0
# 10003     665000.0
# 10004    2300000.0
# 10005    1050000.0
# 10007     270000.0
# Name: Valor_anuncio, Length: 9156, dtype: float64

# %%
dados_vendas["Valor_anuncio_float"] = dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rua                  6107 non-null   object
#  1   Bairro               9146 non-null   object
#  2   Cidade               9156 non-null   object
#  3   Metragem             9156 non-null   int64
#  4   Quartos              9156 non-null   int64
#  5   Banheiros            9156 non-null   int64
#  6   Vagas                9156 non-null   int64
#  7   Valor                9156 non-null   object
#  8   Moeda                9156 non-null   object
#  9   Valor_anuncio        9156 non-null   object
#  10  Tipo_anuncio         0 non-null      object
#  11  Valor_anuncio_float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
dados_vendas["Valor_anuncio_float"].plot.hist(bins = 50)

# %%
pd.set_option("display.precision", 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00

# %%
dados_vendas[["Rua", "Bairro", "Cidade"]].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(10, 8))
ax = sns.histplot(data = dados_vendas, x = "Valor_anuncio_float", kde = True)
ax.set_title("Histograma Valor Imóvel")
plt.xlim((-50, 10000000))
plt.show()

# %% [markdown]
# #Desafio Aula 2
#
# - Criar uma escala de valores em milhões
# - Deixar o gráfico do histograma de valores legível (alterar labels, cores, título, escala)
# - Preço do metro quadrado por bairro e plotar em um gráfico ideal
# - Explorar as bibliotecas de visualizações e colocar as suas conclusão
# - Pesquisar um visualização para analisar os quartis, mediana e outliers

# %%
dados_vendas.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None
#
#    Valor_anuncio_float
# 0           7000000.00
# ...

# %%
dados_vendas["Valor_m2"] = dados_vendas["Valor_anuncio_float"]/dados_vendas["Metragem"]
dados_vendas.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# ...

# %%
dados_vendas.groupby("Bairro").mean()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação            246.16     3.27       3.04   2.91           1763200.01
# Alto da Boa Vista    418.88     4.12       5.12   4.62           2391250.00
# Alto da Lapa         299.25     3.15       3.85   4.00           2083168.75
# Alto da Mooca        270.05     3.30       2.60   3.65           1184170.00
# Alto de Pinheiros    429.85     3.94       4.83   4.95           4782698.96
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda      152.20     2.60       2.20   2.60            652000.00
# Água Branca          173.58     3.08       3.25   2.25           1226500.00
# Água Fria            165.42     2.83       3.42   2.50            927083.33
# Água Funda           139.00     3.00       2.50   2.00            545000.00
# Água Rasa            186.17     2.67       2.00   3.67            716166.67
#
#                    Valor_m2
# Bairro
# ...

# %%
dados_bairro = dados_vendas.groupby("Bairro").sum()
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação             19447      258        240    230         139292801.00
# Alto da Boa Vista      3351       33         41     37          19130000.00
# Alto da Lapa          23940      252        308    320         166653500.00
# Alto da Mooca          5401       66         52     73          23683400.00
# Alto de Pinheiros    158616     1453       1782   1827        1764815915.00
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda         761       13         11     13           3260000.00
# Água Branca            2083       37         39     27          14718000.00
# Água Fria              1985       34         41     30          11125000.00
# Água Funda              278        6          5      4           1090000.00
# Água Rasa              1117       16         12     22           4297000.00
#
#                     Valor_m2
# Bairro
# ...

# %%
dados_bairro["Valor_m2_bairro"] = dados_bairro["Valor_anuncio_float"]/dados_bairro["Metragem"]
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação             19447      258        240    230         139292801.00
# Alto da Boa Vista      3351       33         41     37          19130000.00
# Alto da Lapa          23940      252        308    320         166653500.00
# Alto da Mooca          5401       66         52     73          23683400.00
# Alto de Pinheiros    158616     1453       1782   1827        1764815915.00
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda         761       13         11     13           3260000.00
# Água Branca            2083       37         39     27          14718000.00
# Água Fria              1985       34         41     30          11125000.00
# Água Funda              278        6          5      4           1090000.00
# Água Rasa              1117       16         12     22           4297000.00
#
#                     Valor_m2  Valor_m2_bairro
# ...

# %%
dados_vendas.groupby("Bairro").mean().loc["Vila Mariana"]
# Out:
# Metragem                  231.24
# Quartos                     3.39
# Banheiros                   3.24
# Vagas                       2.95
# Valor_anuncio_float   1771159.76
# Valor_m2                 7913.15
# Name: Vila Mariana, dtype: float64

# %%
dados_bairro.loc["Vila Mariana"]
# Out:
# Metragem                  39079.00
# Quartos                     573.00
# Banheiros                   547.00
# Vagas                       499.00
# Valor_anuncio_float   299326000.00
# Valor_m2                1337323.16
# Valor_m2_bairro            7659.51
# Name: Vila Mariana, dtype: float64

# %%
dados_bairro["Valor_m2_bairro"]["Vila Mariana"]
# Out:
# 7659.510222881855

# %%
top_bairros = dados_vendas["Bairro"].value_counts()[:10].index

# %%
dados_bairro.reset_index(inplace = True)
dados_bairro
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 0            Aclimação     19447      258        240    230
# 1    Alto da Boa Vista      3351       33         41     37
# 2         Alto da Lapa     23940      252        308    320
# 3        Alto da Mooca      5401       66         52     73
# 4    Alto de Pinheiros    158616     1453       1782   1827
# ..                 ...       ...      ...        ...    ...
# 692    Vila Água Funda       761       13         11     13
# 693        Água Branca      2083       37         39     27
# 694          Água Fria      1985       34         41     30
# 695         Água Funda       278        6          5      4
# 696          Água Rasa      1117       16         12     22
#
#      Valor_anuncio_float   Valor_m2  Valor_m2_bairro
# 0           139292801.00  604837.39          7162.69
# 1            19130000.00   46796.55          5708.74
# 2           166653500.00  608538.25          6961.30
# ...

# %%
dados_bairro.query("Bairro in @top_bairros")
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 4    Alto de Pinheiros    158616     1453       1782   1827
# 19   Brooklin Paulista     70002      778        862    832
# 57       Cidade Jardim    132220      789       1008   1172
# 155      Jardim Europa    118898      795        993   1056
# 168     Jardim Guedala    972212     1443       2027   2161
# 187      Jardim Leonor     97141      697        941    902
# 227    Jardim Paulista    130283     1028       1231   1171
# 338           Pacaembu    100285      774        889   1028
# 396  Planalto Paulista     59250      636        768    713
# 564      Vila Madalena     66250      739        786    712
#
#      Valor_anuncio_float   Valor_m2  Valor_m2_bairro
# 4          1764815915.00 4158622.61         11126.34
# 19          475796789.00 1627341.87          6796.90
# 57         1164210900.00 1635692.98          8805.10
# 155        2414172900.00 4192164.45         20304.57
# ...

# %%
plt.figure(figsize=(10, 8))
ax = sns.barplot(x="Bairro", y="Valor_m2_bairro", data=dados_bairro.query("Bairro in @top_bairros"))
ax.tick_params(axis='x', rotation=45)

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas.query("Bairro in @top_bairros"), x="Bairro", y="Valor_anuncio_float")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas.query("Bairro in @top_bairros & Metragem < 30000"), x="Bairro", y="Metragem")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %%
ibge_url = "https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv"
pd.read_csv(ibge_url)
# Out:
#                                                                                                                                                Cod_setor;Cod_Grandes Regi�es;Nome_Grande_Regiao;Cod_UF;Nome_da_UF ;Cod_meso;Nome_da_meso;Cod_micro;Nome_da_micro;Cod_RM;Nome_da_RM;Cod_municipio;Nome_do_municipio;Cod_distrito;Nome_do_distrito;Cod_subdistrito;Nome_do_subdistrito;Cod_bairro;Nome_do_bairro;Situacao_setor;Tipo_setor;V001;V002;V003;V004;V005;V006;V007;V008;V009;V010;V011;V012;
# 355030801000001;3;"Regi�o Sudeste";35;"S�o Paul... 01;2 32;2091 32;8532451           78;2164 55;8673276 78;1227 41;4285771 99;1713 75;5152087                                              86.00
# 355030801000002;3;"Regi�o Sudeste";35;"S�o Paul... 98;2 09;1650 09;3983441           31;1717 44;4030519 99;1045 78;2572133 32;1468 08;2991546                                              94.00
# ...

# %% [markdown]
# ##Desafio Aula 3
#
# - Tentar vincular dados do IBGE com os dados de imóveis.
# - Tratar os outliers e comparar com os resultados.
# - Agrupar por mais de uma categoria e realizar as análises.
# - Organize o colab para deixar com cara de projeto.

# %% [markdown]
# # Tentar vincular dados do IBGE com os dados de imóveis.

# %%
ibge_url = "https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv"

#usando o ; no lugar da , 
ibge = pd.read_csv(ibge_url, sep=';', encoding='latin1')

#tirando colunas que não vai ser usado
ibge.drop(columns=['Cod_setor', 'Cod_Grandes Regiï¿½es', 'Nome_Grande_Regiao', 'Cod_UF',
       'Nome_da_UF ', 'Cod_meso', 'Nome_da_meso', 'Cod_micro', 'Nome_da_micro',
       'Cod_RM', 'Nome_da_RM', 'Cod_distrito', 'Nome_do_distrito', 'Cod_subdistrito',
       'Nome_do_subdistrito', 'Situacao_setor',
       'Tipo_setor'], inplace=True)

ibge.head(5)
# Out:
#    Cod_municipio Nome_do_municipio  Cod_bairro  \
# 0        3550308       Sï¿½O PAULO  3550308000
# 1        3550308       Sï¿½O PAULO  3550308000
# 2        3550308       Sï¿½O PAULO  3550308000
# 3        3550308       Sï¿½O PAULO  3550308000
# 4        3550308       Sï¿½O PAULO  3550308000
#
#                    Nome_do_bairro   V001   V002  V003  V004     V005  \
# 0  Sï¿½O PAULO (todos os setores) 266.00 800.00  3,01  2,32  2091,32
# 1  Sï¿½O PAULO (todos os setores) 306.00 913.00  2,98  2,09  1650,09
# 2  Sï¿½O PAULO (todos os setores) 189.00 625.00  3,31  3,08  1280,43
# 3  Sï¿½O PAULO (todos os setores) 181.00 572.00  3,16  2,26  1119,59
# 4  Sï¿½O PAULO (todos os setores) 240.00 754.00  3,14  2,35   1416,9
#
#          V006     V007        V008     V009        V010     V011        V012  \
# 0  8532451,78  2164,55  8673276,78  1227,41  4285771,99  1713,75  5152087,86
# 1  3983441,31  1717,44  4030519,99  1045,78  2572133,32  1468,08  2991546,94
# ...

# %% [markdown]
# # Tratar os outliers e comparar com os resultados.

# %%
dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float  Valor_m2
# count   9156.00  9156.00    9156.00 9156.00              9156.00   9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96   8004.07
# std     7856.42     1.05       1.97    2.60           3944208.19   5291.32
# min       10.00     1.00       1.00    1.00             13000.00      9.33
# 25%      168.00     3.00       2.00    2.00            890000.00   4750.00
# 50%      276.00     3.00       4.00    4.00           1800000.00   6500.00
# 75%      450.00     4.00       5.00    5.00           3500000.00   9453.78
# max   750000.00    16.00      40.00   50.00          65000000.00  80000.00

# %%
dados_vendas[dados_vendas["Metragem"] > 2000]
# Out:
#                                      Rua            Bairro     Cidade  \
# 1842      Avenida Nova Cantareira, 4337           Tucuruvi  São Paulo
# 1936      Avenida Nova Cantareira, 4337           Tucuruvi  São Paulo
# 2508                                 NaN    Retiro Morumbi  São Paulo
# 4788                  Rua Canuto Borelli      Vila Castelo  São Paulo
# 6600              Rua Benedito Felizardo     Sítio Represa  São Paulo
# 6883                                 NaN  Jardim da Glória  São Paulo
# 6908                                 NaN    Retiro Morumbi  São Paulo
# 7026        Rua General Pereira da Cunha    Retiro Morumbi  São Paulo
# 7067                        Rua Itassuce          Pacaembu  São Paulo
# 7478  Rua General Pereira da Cunha, 505     Retiro Morumbi  São Paulo
# 7791                        Rua Itassuce          Pacaembu  São Paulo
# 7906                        Rua Itassuce          Pacaembu  São Paulo
# ...

# %%
dados_vendas[dados_vendas["Quartos"] > 7]
# Out:
#                                    Rua                        Bairro  \
# 170         Rua Manuel Francisco Alves          Parque Casa de Pedra
# 224                                NaN                  Vila Sabrina
# 457        Avenida IV Centenário, 544               Jardim Luzitânia
# 493                 Rua Turiassu, 189                       Perdizes
# 1127                        Rua Bandim                       Boaçava
# 1145                Rua Murtinho Nobre                       Butantã
# 1179                Rua Murtinho Nobre                       Butantã
# 1273                               NaN                Vila Monumento
# 1589               Rua Sílvio Portugal                      Pacaembu
# 1726                               NaN               Jardim Paulista
# 1897                               NaN                      Pacaembu
# 2724              Alameda Franca, 587                Jardim Paulista
# 2754              Alameda Franca, 587                Jardim Paulista
# ...

# %%
dados_vendas[dados_vendas["Banheiros"] > 9]
# Out:
#                                         Rua                Bairro     Cidade  \
# 614            Rua General Pereira da Cunha        Retiro Morumbi  São Paulo
# 630            Rua General Pereira da Cunha        Retiro Morumbi  São Paulo
# 937          Rua Bandeirante Sampaio Soares          Vila Morumbi  São Paulo
# 1145                     Rua Murtinho Nobre               Butantã  São Paulo
# 1179                     Rua Murtinho Nobre               Butantã  São Paulo
# 1203                   Avenida Piassanguaba     Planalto Paulista  São Paulo
# 1237                                    NaN         Jardim Leonor  São Paulo
# 1324                        Rua Campo Verde         Jardim Europa  São Paulo
# 1378                        Rua Campo Verde         Jardim Europa  São Paulo
# 1494                                    NaN     Alto de Pinheiros  São Paulo
# 1589                    Rua Sílvio Portugal              Pacaembu  São Paulo
# ...

# %%
dados_vendas[dados_vendas["Vagas"] > 10]
# Out:
#                                Rua               Bairro     Cidade  Metragem  \
# 260              Rua dos Franceses   Morro dos Ingleses  São Paulo      1039
# 353                            NaN  Jardim das Camélias  São Paulo      1700
# 400                            NaN        Jardim Europa  São Paulo      1510
# 627          Avenida das Magnólias        Cidade Jardim  São Paulo      1915
# 643          Avenida das Magnólias        Cidade Jardim  São Paulo      1920
# ...                            ...                  ...        ...       ...
# 9362                           NaN              Morumbi  São Paulo      1100
# 9592          Alameda dos Tacaúnas    Planalto Paulista  São Paulo      1300
# 9602                           NaN                Mooca  São Paulo       316
# 9791  Rua General Pereira da Cunha       Retiro Morumbi  São Paulo      2000
# 9871           Rua Todos os Santos       Jardim Everest  São Paulo       755
#
# ...

# %%
#tratar os outlines

f1 = dados_vendas["Metragem"] <= 900
f2 = dados_vendas["Quartos"] <= 8
f3 = dados_vendas["Banheiros"] <= 10
f4 = dados_vendas["Vagas"] <= 9

dados_vendas[f1 & f2 & f3 & f4].head(6)
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 5                 Rua Graham Bell         Santo Amaro  São Paulo       440
# 6        Rua Francisco Paulo, 31    Cidade Mãe do Céu  São Paulo       145
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None
# ...

# %%
dados_vendas[f1 & f2 & f3 & f4].describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float  Valor_m2
# count   8552.00  8552.00    8552.00 8552.00              8552.00   8552.00
# mean     306.66     3.36       3.63    3.55           2600320.44   7818.09
# std      182.77     0.94       1.76    1.79           2899188.82   4982.29
# min       10.00     1.00       1.00    1.00             13000.00     34.40
# 25%      160.00     3.00       2.00    2.00            850000.00   4720.93
# 50%      259.00     3.00       3.00    3.00           1690000.00   6417.98
# 75%      408.00     4.00       5.00    5.00           3200000.00   9259.26
# max      900.00     8.00      10.00    9.00          30000000.00  80000.00

# %%
#gráfico para mostrar a metragem dos bairros

plt.figure(figsize=(20,8))
ax = sns.boxplot(x="Bairro", y="Metragem", hue="Bairro", data=dados_vendas[f1 & f2 & f3 & f4].query("Bairro in @top_bairros"))
ax.tick_params(axis='x', rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,8))
ax = sns.boxplot(x="Bairro", y="Quartos", hue="Bairro", data=dados_vendas[f1 & f2 & f3 & f4].query("Bairro in @top_bairros"))
ax.tick_params(axis='x', rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,8))
ax = sns.boxplot(x="Bairro", y="Banheiros", hue="Bairro", data=dados_vendas[f1 & f2 & f3 & f4].query("Bairro in @top_bairros"))
ax.tick_params(axis='x', rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,8))
ax = sns.boxplot(x="Bairro", y="Vagas", hue="Bairro", data=dados_vendas[f1 & f2 & f3 & f4].query("Bairro in @top_bairros"))
ax.tick_params(axis='x', rotation=90)
plt.show()

# %% [markdown]
# #Agrupar por mais de uma categoria e realizar as análises.

# %%
venda_bairro_pinheiros = dados_vendas[dados_vendas.Bairro == 'Alto de Pinheiros']
venda_bairro_pinheiros
# Out:
#                            Rua             Bairro     Cidade  Metragem  \
# 83       Rua Carlos Rath, 103   Alto de Pinheiros  São Paulo       400
# 84                         NaN  Alto de Pinheiros  São Paulo       358
# 137         Rua Aquiramun, 94   Alto de Pinheiros  São Paulo       450
# 214             Rua Açaré, 63   Alto de Pinheiros  São Paulo       252
# 227                        NaN  Alto de Pinheiros  São Paulo       360
# ...                        ...                ...        ...       ...
# 9691                       NaN  Alto de Pinheiros  São Paulo       466
# 9696   Rua Sebastião Rodrigues  Alto de Pinheiros  São Paulo       150
# 9727                       NaN  Alto de Pinheiros  São Paulo       466
# 9732   Rua Sebastião Rodrigues  Alto de Pinheiros  São Paulo       150
# 9893  Rua Cardeal Cagliori, 1   Alto de Pinheiros  São Paulo       400
#
#       Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %%
venda_bairro_pinheiros.groupby(["Bairro", "Quartos"])["Valor_m2"].describe()
# Out:
#                            count     mean     std      min      25%      50%  \
# Bairro            Quartos
# Alto de Pinheiros 2         1.00 11166.67     NaN 11166.67 11166.67 11166.67
#                   3        87.00 11462.71 3704.89  3495.44  9000.00 10819.67
#                   4       224.00 11052.69 3634.34  4462.69  8587.26 10694.03
#                   5        51.00 11946.38 4996.00  5535.71  7684.89 10536.40
#                   6         3.00 16003.20 8410.12 11111.11 11147.66 11184.21
#                   7         3.00  5707.25   35.61  5686.70  5686.70  5686.70
#
#                                75%      max
# Bairro            Quartos
# Alto de Pinheiros 2       11166.67 11166.67
#                   3       13576.03 22985.78
#                   4       12912.94 25172.89
#                   5       13882.75 22727.27
#                   6       18449.25 25714.29
#                   7        5717.53  5748.37

# %%
venda_bairro_pinheiros.groupby(["Bairro", "Quartos"]).sum()
# Out:
#                            Metragem  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro            Quartos
# Alto de Pinheiros 2             300          4      2           3350000.00
#                   3           30924        382    400         331409000.00
#                   4           99828       1090   1107        1085776915.00
#                   5           23946        273    279         301330000.00
#                   6            2225         15     18          35000000.00
#                   7            1393         18     21           7950000.00
#
#                             Valor_m2
# Bairro            Quartos
# Alto de Pinheiros 2         11166.67
#                   3        997255.77
#                   4       2475803.43
#                   5        609265.37
#                   6         48009.61
#                   7         17121.76

# %%
venda_bairro_pinheiros.groupby(["Bairro", "Quartos"]).sum().describe()
# Out:
#        Metragem  Banheiros   Vagas  Valor_anuncio_float   Valor_m2
# count      6.00       6.00    6.00                 6.00       6.00
# mean   26436.00     297.00  304.50         294135985.83  693103.77
# std    38233.87     419.49  426.08         415149794.50  960800.89
# min      300.00       4.00    2.00           3350000.00   11166.67
# 25%     1601.00      15.75   18.75          14712500.00   24843.72
# 50%    13085.50     145.50  150.00         168165000.00  328637.49
# 75%    29179.50     354.75  369.75         323889250.00  900258.17
# max    99828.00    1090.00 1107.00        1085776915.00 2475803.43

# %%
venda_bairro_pinheiros.groupby(["Bairro", "Banheiros"]).sum()
# Out:
#                              Metragem  Quartos  Vagas  Valor_anuncio_float  \
# Bairro            Banheiros
# Alto de Pinheiros 1              3103       29     36          29240000.00
#                   2              5258       63     82          62230000.00
#                   3             17934      177    189         181281000.00
#                   4             28529      268    317         319420000.00
#                   5             45953      422    538         485438880.00
#                   6             34412      294    388         401865875.00
#                   7             17869      159    202         233051160.00
#                   8              4281       32     60          39889000.00
#                   10              555        5      5           6200000.00
#                   11              722        4     10           6200000.00
#
#                               Valor_m2
# Bairro            Banheiros
# Alto de Pinheiros 1           65406.92
# ...

# %%
venda_bairro_pinheiros.groupby(['Bairro', 'Banheiros']).sum().describe()
# Out:
#        Metragem  Quartos  Vagas  Valor_anuncio_float   Valor_m2
# count     10.00    10.00  10.00                10.00      10.00
# mean   15861.60   145.30 182.70         176481591.50  415862.26
# std    15955.58   144.42 181.03         176789237.25  407691.27
# min      555.00     4.00   5.00           6200000.00    8587.26
# 25%     3397.50    29.75  42.00          31902250.00   68151.78
# 50%    11563.50   111.00 135.50         121755500.00  350592.40
# 75%    25880.25   245.25 288.25         297827790.00  734959.96
# max    45953.00   422.00 538.00         485438880.00 1146098.34

# %%
venda_bairro_pinheiros.groupby(["Bairro", "Vagas"]).sum()
# Out:
#                          Metragem  Quartos  Banheiros  Valor_anuncio_float  \
# Bairro            Vagas
# Alto de Pinheiros 1           100        3          2           1180000.00
#                   2          5905       60         73          57550000.00
#                   3         15927      151        177         178730000.00
#                   4         57492      555        663         653514915.00
#                   5         24355      231        293         275697000.00
#                   6         26040      221        264         269040000.00
#                   7         10181       97        110         144350000.00
#                   8          8771       61         84          88700000.00
#                   9           570        4          7           3290000.00
#                   10         5345       32         63          53369000.00
#                   12         2665       28         32          19395000.00
# ...

# %%
venda_bairro_pinheiros.groupby(["Bairro", "Vagas"]).sum().describe()
# Out:
#        Metragem  Quartos  Banheiros  Valor_anuncio_float   Valor_m2
# count     13.00    13.00      13.00                13.00      13.00
# mean   12201.23   111.77     137.08         135755070.38  319894.05
# std    16194.64   155.25     185.26         183327133.24  449080.90
# min      100.00     3.00       2.00           1180000.00    5771.93
# 25%      660.00     6.00      12.00          13000000.00   23142.08
# 50%     5905.00    60.00      73.00          57550000.00  149919.86
# 75%    15927.00   151.00     177.00         178730000.00  493344.48
# max    57492.00   555.00     663.00         653514915.00 1612044.74

# %% [markdown]
# # CONCLUSÃO
#
# A análise demonstra que o valor médio por metro quadrado nos quartos é mais significativa comparada com o valor médio pelos banheiros e vagas de garagem.
# Ou seja, os quartos tem muito mais valor por metro quadrado do que as vagas.
